# %%
import sys
import sklearn
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.cluster import MiniBatchKMeans

print(f'Python: {sys.version}')
print(f'NumPy: {np.version}')
# Out:
# Python: 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# NumPy: <module 'numpy.version' from '/usr/local/lib/python3.7/dist-packages/numpy/version.py'>

# %%
# Download the dataset 
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(
    path='mnist.npz'
)
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Convert each image to 1 dimensional array
X = train_images.reshape(len(train_images),-1)
Y = train_labels
K = test_images.reshape(len(test_images),-1)
J = test_labels

# %%
# Clustering on the training dataset
n_digits = 120
kmeans = MiniBatchKMeans(n_clusters = n_digits, max_iter=10000, n_init=50)
kmeans.fit(X)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=10000, max_no_improvement=10,
#                 n_clusters=120, n_init=50, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
# Center of the clusters
from sklearn.metrics import pairwise_distances, pairwise_distances_argmin_min
# find the closest sample to the center of each cluster
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, X)
# Map cluster to digit by using only the label of the closest element to the center
map_pred2digits ={}
# Map cluster to digit by using the most frequent label in the cluster 
# We won't use this for the rest of the experiment as it requires all the labels
map_pred2digits_with_all_labels ={}
predictions = kmeans.predict(X)

for cidx, c in enumerate(closest):
  map_pred2digits_with_all_labels[cidx] = np.argmax(np.bincount(Y[predictions==cidx]))
  map_pred2digits[cidx] = Y[c]

# Label all the dataset based on the label of the center of the clusters
dirty_labels = np.vectorize(map_pred2digits.get)(predictions)

# %%
# Evaluation on validation dataset
from sklearn.metrics import accuracy_score
predictions = kmeans.predict(K)
digits_predictions = np.vectorize(map_pred2digits.get)(predictions)
print('Accuracy using the label of the center of the cluster ',accuracy_score(J,digits_predictions))
digits_predictions = np.vectorize(map_pred2digits_with_all_labels.get)(predictions)
print('Accuracy if we had all the labels ', accuracy_score(J,digits_predictions))
# Out:
# Accuracy using the label of the center of the cluster  0.8674
# Accuracy if we had all the labels  0.8702

# %% [markdown]
# # DIRTY LABELS ( Use the entire training dataset labelled with the
# #                 label of the closest sample to the center of each cluster )

# %%
# CNN with heavy dropout
input_shape = (28, 28, 1)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu', input_shape=input_shape))
model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
test_images = test_images.reshape(test_images.shape[0],28,28,1)
train_images = train_images.reshape(train_images.shape[0],28,28,1)

# %%
# DIRTY LABELS ( Use the entire training dataset labelled with the 
#                 label of closest sample to the center of the cluster )
n_epochs = 6
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)
model.fit(train_images, dirty_labels, validation_data = (test_images,  test_labels), 
          epochs=n_epochs, verbose = 1, callbacks=[model_checkpoint_callback])
model.load_weights(checkpoint_filepath)
model.evaluate(test_images,  test_labels)
# Out:
# Epoch 1/6
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 1875/1875 [==============================] - 60s 4ms/step - loss: 0.4387 - accuracy: 0.8550 - val_loss: 0.3055 - val_accuracy: 0.9050
# Epoch 2/6
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3167 - accuracy: 0.8917 - val_loss: 0.3243 - val_accuracy: 0.9063
# Epoch 3/6
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2840 - accuracy: 0.9011 - val_loss: 0.3553 - val_accuracy: 0.9007
# Epoch 4/6
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2626 - accuracy: 0.9081 - val_loss: 0.3736 - val_accuracy: 0.8962
# Epoch 5/6
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2461 - accuracy: 0.9150 - val_loss: 0.3768 - val_accuracy: 0.8879
# Epoch 6/6
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2337 - accuracy: 0.9172 - val_loss: 0.3839 - val_accuracy: 0.8888
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3243 - accuracy: 0.9063
# [0.3242577314376831, 0.9063000082969666]

# %% [markdown]
# # ONLY TRAIN WITH THE CLUSTER CENTROIDS

# %%
# CNN with heavy dropout
input_shape = (28, 28, 1)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu', input_shape=input_shape))
model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
test_images = test_images.reshape(test_images.shape[0],28,28,1)
train_images = train_images.reshape(train_images.shape[0],28,28,1)

# %%
# ONLY TRAIN WITH THE CLUSTER CENTERS
labelled_indices = closest
labelled_indices.shape, np.bincount(train_labels[labelled_indices])
n_epochs = 250

# %%
model.fit(train_images[labelled_indices], train_labels[labelled_indices], validation_data = (test_images,  test_labels), epochs=n_epochs, verbose = 1)
model.evaluate(test_images,  test_labels)
# Out:
# Epoch 1/250
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 4/4 [==============================] - 2s 347ms/step - loss: 3.0027 - accuracy: 0.2167 - val_loss: 2.2793 - val_accuracy: 0.2141
# Epoch 2/250
# 4/4 [==============================] - 1s 199ms/step - loss: 1.0634 - accuracy: 0.6000 - val_loss: 2.2558 - val_accuracy: 0.5231
# Epoch 3/250
# 4/4 [==============================] - 1s 199ms/step - loss: 0.6089 - accuracy: 0.8000 - val_loss: 2.2344 - val_accuracy: 0.6053
# Epoch 4/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.3499 - accuracy: 0.9000 - val_loss: 2.2183 - val_accuracy: 0.5192
# Epoch 5/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.1704 - accuracy: 0.9583 - val_loss: 2.2043 - val_accuracy: 0.2531
# Epoch 6/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.1099 - accuracy: 0.9917 - val_loss: 2.1947 - val_accuracy: 0.1439
# Epoch 7/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.1556 - accuracy: 0.9583 - val_loss: 2.1895 - val_accuracy: 0.1141
# Epoch 8/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 2.1908 - val_accuracy: 0.1135
# Epoch 9/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0476 - accuracy: 1.0000 - val_loss: 2.2004 - val_accuracy: 0.1135
# Epoch 10/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0556 - accuracy: 0.9917 - val_loss: 2.2201 - val_accuracy: 0.1135
# Epoch 11/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0442 - accuracy: 0.9917 - val_loss: 2.2468 - val_accuracy: 0.1135
# Epoch 12/250
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 2.2883 - val_accuracy: 0.1135
# Epoch 13/250
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0327 - accuracy: 0.9917 - val_loss: 2.3438 - val_accuracy: 0.1135
# Epoch 14/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0265 - accuracy: 0.9917 - val_loss: 2.4082 - val_accuracy: 0.1135
# Epoch 15/250
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0218 - accuracy: 0.9917 - val_loss: 2.4779 - val_accuracy: 0.1135
# Epoch 16/250
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 2.5526 - val_accuracy: 0.1135
# Epoch 17/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 2.6313 - val_accuracy: 0.1135
# Epoch 18/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0280 - accuracy: 0.9917 - val_loss: 2.7199 - val_accuracy: 0.1135
# Epoch 19/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 2.8186 - val_accuracy: 0.1135
# Epoch 20/250
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0177 - accuracy: 0.9917 - val_loss: 2.9196 - val_accuracy: 0.1135
# Epoch 21/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 3.0202 - val_accuracy: 0.1135
# Epoch 22/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0205 - accuracy: 0.9917 - val_loss: 3.1367 - val_accuracy: 0.1135
# Epoch 23/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0174 - accuracy: 0.9917 - val_loss: 3.2528 - val_accuracy: 0.1135
# Epoch 24/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 3.3612 - val_accuracy: 0.1135
# Epoch 25/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 3.4759 - val_accuracy: 0.1135
# Epoch 26/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 3.5891 - val_accuracy: 0.1135
# Epoch 27/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.6976 - val_accuracy: 0.1135
# Epoch 28/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.8144 - val_accuracy: 0.1135
# Epoch 29/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0145 - accuracy: 0.9917 - val_loss: 3.9673 - val_accuracy: 0.1135
# Epoch 30/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 4.1065 - val_accuracy: 0.1135
# Epoch 31/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 4.2279 - val_accuracy: 0.1135
# Epoch 32/250
# 4/4 [==============================] - 1s 216ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 4.3443 - val_accuracy: 0.1135
# Epoch 33/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 4.4650 - val_accuracy: 0.1135
# Epoch 34/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 4.5920 - val_accuracy: 0.1135
# Epoch 35/250
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 4.7255 - val_accuracy: 0.1135
# Epoch 36/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 4.8519 - val_accuracy: 0.1135
# Epoch 37/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 4.9848 - val_accuracy: 0.1135
# Epoch 38/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 5.1771 - val_accuracy: 0.1135
# Epoch 39/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 5.3266 - val_accuracy: 0.1135
# Epoch 40/250
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 5.4442 - val_accuracy: 0.1135
# Epoch 41/250
# 4/4 [==============================] - 1s 213ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 5.5635 - val_accuracy: 0.1135
# Epoch 42/250
# 4/4 [==============================] - 1s 213ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 5.6943 - val_accuracy: 0.1135
# Epoch 43/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 5.8141 - val_accuracy: 0.1135
# Epoch 44/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 5.9153 - val_accuracy: 0.1135
# Epoch 45/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 6.0353 - val_accuracy: 0.1135
# Epoch 46/250
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.1496 - val_accuracy: 0.1135
# Epoch 47/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 6.2696 - val_accuracy: 0.1135
# Epoch 48/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 6.3728 - val_accuracy: 0.1135
# Epoch 49/250
# 4/4 [==============================] - 1s 207ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 6.4589 - val_accuracy: 0.1135
# Epoch 50/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 6.5399 - val_accuracy: 0.1135
# Epoch 51/250
# 4/4 [==============================] - 1s 208ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 6.6193 - val_accuracy: 0.1135
# Epoch 52/250
# 4/4 [==============================] - 1s 218ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 6.6847 - val_accuracy: 0.1135
# Epoch 53/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 6.7487 - val_accuracy: 0.1135
# Epoch 54/250
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 6.8113 - val_accuracy: 0.1135
# Epoch 55/250
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0120 - accuracy: 0.9917 - val_loss: 6.8793 - val_accuracy: 0.1135
# Epoch 56/250
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 6.9605 - val_accuracy: 0.1135
# Epoch 57/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.0230 - val_accuracy: 0.1135
# Epoch 58/250
# 4/4 [==============================] - 1s 217ms/step - loss: 8.3740e-04 - accuracy: 1.0000 - val_loss: 7.0687 - val_accuracy: 0.1135
# Epoch 59/250
# 4/4 [==============================] - 1s 214ms/step - loss: 9.3525e-04 - accuracy: 1.0000 - val_loss: 7.1107 - val_accuracy: 0.1135
# Epoch 60/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 7.1703 - val_accuracy: 0.1135
# Epoch 61/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 7.2382 - val_accuracy: 0.1135
# Epoch 62/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 7.2943 - val_accuracy: 0.1135
# Epoch 63/250
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 7.3274 - val_accuracy: 0.1135
# Epoch 64/250
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 7.3393 - val_accuracy: 0.1135
# Epoch 65/250
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 7.3401 - val_accuracy: 0.1135
# Epoch 66/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 7.3486 - val_accuracy: 0.1135
# Epoch 67/250
# 4/4 [==============================] - 1s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.3569 - val_accuracy: 0.1135
# Epoch 68/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 7.3611 - val_accuracy: 0.1135
# Epoch 69/250
# 4/4 [==============================] - 1s 216ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 7.3574 - val_accuracy: 0.1135
# Epoch 70/250
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 7.3488 - val_accuracy: 0.1135
# Epoch 71/250
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 7.3332 - val_accuracy: 0.1135
# Epoch 72/250
# 4/4 [==============================] - 1s 430ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 7.3170 - val_accuracy: 0.1135
# Epoch 73/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 7.3380 - val_accuracy: 0.1135
# Epoch 74/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 7.3960 - val_accuracy: 0.1135
# Epoch 75/250
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 7.4224 - val_accuracy: 0.1135
# Epoch 76/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 7.4215 - val_accuracy: 0.1135
# Epoch 77/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.4062 - val_accuracy: 0.1135
# Epoch 78/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 7.3599 - val_accuracy: 0.1135
# Epoch 79/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 7.2911 - val_accuracy: 0.1135
# Epoch 80/250
# 4/4 [==============================] - 1s 216ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 7.1232 - val_accuracy: 0.1135
# Epoch 81/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.8738 - val_accuracy: 0.1135
# Epoch 82/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 6.7055 - val_accuracy: 0.1135
# Epoch 83/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.6431 - val_accuracy: 0.1135
# Epoch 84/250
# 4/4 [==============================] - 1s 208ms/step - loss: 8.7225e-04 - accuracy: 1.0000 - val_loss: 6.5745 - val_accuracy: 0.1135
# Epoch 85/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.5030 - val_accuracy: 0.1136
# Epoch 86/250
# 4/4 [==============================] - 1s 217ms/step - loss: 8.9124e-04 - accuracy: 1.0000 - val_loss: 6.4287 - val_accuracy: 0.1136
# Epoch 87/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 6.3609 - val_accuracy: 0.1136
# Epoch 88/250
# 4/4 [==============================] - 1s 207ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 6.3887 - val_accuracy: 0.1136
# Epoch 89/250
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 6.3734 - val_accuracy: 0.1136
# Epoch 90/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 6.3293 - val_accuracy: 0.1138
# Epoch 91/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 6.2966 - val_accuracy: 0.1142
# Epoch 92/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 6.2508 - val_accuracy: 0.1150
# Epoch 93/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 6.1476 - val_accuracy: 0.1182
# Epoch 94/250
# 4/4 [==============================] - 1s 209ms/step - loss: 8.6613e-04 - accuracy: 1.0000 - val_loss: 6.0266 - val_accuracy: 0.1209
# Epoch 95/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 5.8965 - val_accuracy: 0.1240
# Epoch 96/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 5.7970 - val_accuracy: 0.1263
# Epoch 97/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 5.7009 - val_accuracy: 0.1282
# Epoch 98/250
# 4/4 [==============================] - 1s 217ms/step - loss: 9.9237e-04 - accuracy: 1.0000 - val_loss: 5.5765 - val_accuracy: 0.1319
# Epoch 99/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 5.4371 - val_accuracy: 0.1356
# Epoch 100/250
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 5.3497 - val_accuracy: 0.1375
# Epoch 101/250
# 4/4 [==============================] - 1s 213ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.2620 - val_accuracy: 0.1410
# Epoch 102/250
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 5.1754 - val_accuracy: 0.1428
# Epoch 103/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.0424 - val_accuracy: 0.1463
# Epoch 104/250
# 4/4 [==============================] - 1s 218ms/step - loss: 8.1473e-04 - accuracy: 1.0000 - val_loss: 4.8875 - val_accuracy: 0.1503
# Epoch 105/250
# 4/4 [==============================] - 1s 218ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.7332 - val_accuracy: 0.1537
# Epoch 106/250
# 4/4 [==============================] - 1s 215ms/step - loss: 5.0650e-04 - accuracy: 1.0000 - val_loss: 4.5742 - val_accuracy: 0.1584
# Epoch 107/250
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0312 - accuracy: 0.9917 - val_loss: 4.5016 - val_accuracy: 0.1627
# Epoch 108/250
# 4/4 [==============================] - 1s 212ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.3709 - val_accuracy: 0.1683
# Epoch 109/250
# 4/4 [==============================] - 1s 211ms/step - loss: 9.2698e-04 - accuracy: 1.0000 - val_loss: 4.2057 - val_accuracy: 0.1742
# Epoch 110/250
# 4/4 [==============================] - 1s 222ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 4.0724 - val_accuracy: 0.1779
# Epoch 111/250
# 4/4 [==============================] - 1s 213ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.8923 - val_accuracy: 0.1869
# Epoch 112/250
# 4/4 [==============================] - 1s 219ms/step - loss: 8.4624e-04 - accuracy: 1.0000 - val_loss: 3.6916 - val_accuracy: 0.1986
# Epoch 113/250
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.4957 - val_accuracy: 0.2112
# Epoch 114/250
# 4/4 [==============================] - 1s 212ms/step - loss: 6.6459e-04 - accuracy: 1.0000 - val_loss: 3.3141 - val_accuracy: 0.2252
# Epoch 115/250
# 4/4 [==============================] - 1s 213ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.1555 - val_accuracy: 0.2435
# Epoch 116/250
# 4/4 [==============================] - 1s 432ms/step - loss: 0.0110 - accuracy: 0.9917 - val_loss: 3.0066 - val_accuracy: 0.2634
# Epoch 117/250
# 4/4 [==============================] - 1s 220ms/step - loss: 2.0531e-04 - accuracy: 1.0000 - val_loss: 2.8562 - val_accuracy: 0.2936
# Epoch 118/250
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.7033 - val_accuracy: 0.3284
# Epoch 119/250
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.5545 - val_accuracy: 0.3572
# Epoch 120/250
# 4/4 [==============================] - 1s 431ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.3902 - val_accuracy: 0.3927
# Epoch 121/250
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 2.1325 - val_accuracy: 0.4411
# Epoch 122/250
# 4/4 [==============================] - 1s 214ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.9157 - val_accuracy: 0.4845
# Epoch 123/250
# 4/4 [==============================] - 1s 210ms/step - loss: 7.0040e-04 - accuracy: 1.0000 - val_loss: 1.7680 - val_accuracy: 0.5176
# Epoch 124/250
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.6623 - val_accuracy: 0.5450
# Epoch 125/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5843 - val_accuracy: 0.5636
# Epoch 126/250
# 4/4 [==============================] - 1s 202ms/step - loss: 6.5387e-04 - accuracy: 1.0000 - val_loss: 1.5159 - val_accuracy: 0.5818
# Epoch 127/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4469 - val_accuracy: 0.6007
# Epoch 128/250
# 4/4 [==============================] - 1s 200ms/step - loss: 9.2113e-04 - accuracy: 1.0000 - val_loss: 1.3845 - val_accuracy: 0.6173
# Epoch 129/250
# 4/4 [==============================] - 1s 206ms/step - loss: 2.8307e-04 - accuracy: 1.0000 - val_loss: 1.3233 - val_accuracy: 0.6348
# Epoch 130/250
# 4/4 [==============================] - 1s 209ms/step - loss: 8.0513e-04 - accuracy: 1.0000 - val_loss: 1.2696 - val_accuracy: 0.6503
# Epoch 131/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0126 - accuracy: 0.9917 - val_loss: 1.2480 - val_accuracy: 0.6560
# Epoch 132/250
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.3037 - val_accuracy: 0.6373
# Epoch 133/250
# 4/4 [==============================] - 1s 200ms/step - loss: 6.8589e-04 - accuracy: 1.0000 - val_loss: 1.3066 - val_accuracy: 0.6324
# Epoch 134/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.2718 - val_accuracy: 0.6416
# Epoch 135/250
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2139 - val_accuracy: 0.6579
# Epoch 136/250
# 4/4 [==============================] - 1s 216ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1591 - val_accuracy: 0.6745
# Epoch 137/250
# 4/4 [==============================] - 1s 196ms/step - loss: 6.7629e-04 - accuracy: 1.0000 - val_loss: 1.1131 - val_accuracy: 0.6852
# Epoch 138/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.6960
# Epoch 139/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.7178
# Epoch 140/250
# 4/4 [==============================] - 1s 197ms/step - loss: 3.6519e-04 - accuracy: 1.0000 - val_loss: 0.9184 - val_accuracy: 0.7381
# Epoch 141/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.7514
# Epoch 142/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0140 - accuracy: 0.9917 - val_loss: 0.8006 - val_accuracy: 0.7712
# Epoch 143/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.7361 - val_accuracy: 0.7884
# Epoch 144/250
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.6836 - val_accuracy: 0.8051
# Epoch 145/250
# 4/4 [==============================] - 1s 206ms/step - loss: 5.2603e-04 - accuracy: 1.0000 - val_loss: 0.6359 - val_accuracy: 0.8185
# Epoch 146/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0074 - accuracy: 0.9917 - val_loss: 0.6439 - val_accuracy: 0.8172
# Epoch 147/250
# 4/4 [==============================] - 1s 202ms/step - loss: 7.5383e-04 - accuracy: 1.0000 - val_loss: 0.6971 - val_accuracy: 0.8050
# Epoch 148/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.8003
# Epoch 149/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0105 - accuracy: 0.9917 - val_loss: 0.7041 - val_accuracy: 0.8035
# Epoch 150/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.7012 - val_accuracy: 0.8047
# Epoch 151/250
# 4/4 [==============================] - 1s 200ms/step - loss: 3.8866e-04 - accuracy: 1.0000 - val_loss: 0.6948 - val_accuracy: 0.8065
# Epoch 152/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6805 - val_accuracy: 0.8107
# Epoch 153/250
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6553 - val_accuracy: 0.8167
# Epoch 154/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6308 - val_accuracy: 0.8245
# Epoch 155/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 0.8304
# Epoch 156/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6072 - val_accuracy: 0.8315
# Epoch 157/250
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0120 - accuracy: 0.9917 - val_loss: 0.5754 - val_accuracy: 0.8398
# Epoch 158/250
# 4/4 [==============================] - 1s 197ms/step - loss: 6.6582e-04 - accuracy: 1.0000 - val_loss: 0.5742 - val_accuracy: 0.8459
# Epoch 159/250
# 4/4 [==============================] - 1s 207ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5332 - val_accuracy: 0.8600
# Epoch 160/250
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0179 - accuracy: 0.9917 - val_loss: 0.4433 - val_accuracy: 0.8827
# Epoch 161/250
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4832 - val_accuracy: 0.8752
# Epoch 162/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0128 - accuracy: 0.9917 - val_loss: 0.4684 - val_accuracy: 0.8791
# Epoch 163/250
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8885
# Epoch 164/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 0.8960
# Epoch 165/250
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4020 - val_accuracy: 0.8955
# Epoch 166/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4221 - val_accuracy: 0.8933
# Epoch 167/250
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.8916
# Epoch 168/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4401 - val_accuracy: 0.8911
# Epoch 169/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4465 - val_accuracy: 0.8896
# Epoch 170/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4294 - val_accuracy: 0.8961
# Epoch 171/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4465 - val_accuracy: 0.8953
# Epoch 172/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.8896
# Epoch 173/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0148 - accuracy: 0.9917 - val_loss: 0.5241 - val_accuracy: 0.8826
# Epoch 174/250
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.8823
# Epoch 175/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8841
# Epoch 176/250
# 4/4 [==============================] - 1s 205ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.8834
# Epoch 177/250
# 4/4 [==============================] - 1s 200ms/step - loss: 8.4245e-04 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 0.8836
# Epoch 178/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8840
# Epoch 179/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.8927
# Epoch 180/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4508 - val_accuracy: 0.8952
# Epoch 181/250
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0065 - accuracy: 0.9917 - val_loss: 0.4494 - val_accuracy: 0.8960
# Epoch 182/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8960
# Epoch 183/250
# 4/4 [==============================] - 1s 196ms/step - loss: 3.3848e-04 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.8953
# Epoch 184/250
# 4/4 [==============================] - 1s 200ms/step - loss: 4.0396e-04 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.8954
# Epoch 185/250
# 4/4 [==============================] - 1s 193ms/step - loss: 8.9481e-04 - accuracy: 1.0000 - val_loss: 0.4527 - val_accuracy: 0.8960
# Epoch 186/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4475 - val_accuracy: 0.8965
# Epoch 187/250
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 0.8976
# Epoch 188/250
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4360 - val_accuracy: 0.8997
# Epoch 189/250
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4297 - val_accuracy: 0.9015
# Epoch 190/250
# 4/4 [==============================] - 1s 199ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4256 - val_accuracy: 0.9024
# Epoch 191/250
# 4/4 [==============================] - 1s 208ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.9030
# Epoch 192/250
# 4/4 [==============================] - 1s 217ms/step - loss: 4.0744e-04 - accuracy: 1.0000 - val_loss: 0.4184 - val_accuracy: 0.9034
# Epoch 193/250
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.9041
# Epoch 194/250
# 4/4 [==============================] - 1s 213ms/step - loss: 7.6646e-04 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.9051
# Epoch 195/250
# 4/4 [==============================] - 1s 217ms/step - loss: 2.2470e-04 - accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.9047
# Epoch 196/250
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 0.9072
# Epoch 197/250
# 4/4 [==============================] - 1s 214ms/step - loss: 2.2621e-04 - accuracy: 1.0000 - val_loss: 0.4063 - val_accuracy: 0.9078
# Epoch 198/250
# 4/4 [==============================] - 1s 216ms/step - loss: 1.9646e-04 - accuracy: 1.0000 - val_loss: 0.4060 - val_accuracy: 0.9068
# Epoch 199/250
# 4/4 [==============================] - 1s 213ms/step - loss: 8.5859e-04 - accuracy: 1.0000 - val_loss: 0.4066 - val_accuracy: 0.9068
# Epoch 200/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4042 - val_accuracy: 0.9070
# Epoch 201/250
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4039 - val_accuracy: 0.9055
# Epoch 202/250
# 4/4 [==============================] - 1s 211ms/step - loss: 7.0755e-04 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.9045
# Epoch 203/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4027 - val_accuracy: 0.9052
# Epoch 204/250
# 4/4 [==============================] - 1s 213ms/step - loss: 6.3273e-04 - accuracy: 1.0000 - val_loss: 0.4020 - val_accuracy: 0.9049
# Epoch 205/250
# 4/4 [==============================] - 1s 208ms/step - loss: 1.1866e-04 - accuracy: 1.0000 - val_loss: 0.4013 - val_accuracy: 0.9048
# Epoch 206/250
# 4/4 [==============================] - 1s 219ms/step - loss: 1.5004e-04 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.9051
# Epoch 207/250
# 4/4 [==============================] - 1s 212ms/step - loss: 1.0928e-04 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.9051
# Epoch 208/250
# 4/4 [==============================] - 1s 210ms/step - loss: 6.1392e-04 - accuracy: 1.0000 - val_loss: 0.4007 - val_accuracy: 0.9055
# Epoch 209/250
# 4/4 [==============================] - 1s 215ms/step - loss: 5.6042e-04 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.9065
# Epoch 210/250
# 4/4 [==============================] - 1s 210ms/step - loss: 5.3109e-04 - accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.9071
# Epoch 211/250
# 4/4 [==============================] - 1s 431ms/step - loss: 1.0208e-04 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.9075
# Epoch 212/250
# 4/4 [==============================] - 1s 213ms/step - loss: 3.2301e-04 - accuracy: 1.0000 - val_loss: 0.3987 - val_accuracy: 0.9076
# Epoch 213/250
# 4/4 [==============================] - 1s 218ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.9079
# Epoch 214/250
# 4/4 [==============================] - 1s 221ms/step - loss: 2.7118e-04 - accuracy: 1.0000 - val_loss: 0.3974 - val_accuracy: 0.9081
# Epoch 215/250
# 4/4 [==============================] - 1s 208ms/step - loss: 2.7573e-04 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.9086
# Epoch 216/250
# 4/4 [==============================] - 1s 215ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3974 - val_accuracy: 0.9088
# Epoch 217/250
# 4/4 [==============================] - 1s 220ms/step - loss: 2.0575e-04 - accuracy: 1.0000 - val_loss: 0.3974 - val_accuracy: 0.9087
# Epoch 218/250
# 4/4 [==============================] - 1s 218ms/step - loss: 1.6292e-04 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.9089
# Epoch 219/250
# 4/4 [==============================] - 1s 213ms/step - loss: 8.8966e-04 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 0.9093
# Epoch 220/250
# 4/4 [==============================] - 1s 218ms/step - loss: 5.1270e-04 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.9094
# Epoch 221/250
# 4/4 [==============================] - 1s 213ms/step - loss: 9.0172e-05 - accuracy: 1.0000 - val_loss: 0.4019 - val_accuracy: 0.9092
# Epoch 222/250
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4009 - val_accuracy: 0.9097
# Epoch 223/250
# 4/4 [==============================] - 1s 218ms/step - loss: 5.4004e-05 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.9101
# Epoch 224/250
# 4/4 [==============================] - 1s 217ms/step - loss: 8.1501e-05 - accuracy: 1.0000 - val_loss: 0.3996 - val_accuracy: 0.9106
# Epoch 225/250
# 4/4 [==============================] - 1s 216ms/step - loss: 2.8065e-04 - accuracy: 1.0000 - val_loss: 0.3997 - val_accuracy: 0.9110
# Epoch 226/250
# 4/4 [==============================] - 1s 220ms/step - loss: 6.3338e-04 - accuracy: 1.0000 - val_loss: 0.3998 - val_accuracy: 0.9109
# Epoch 227/250
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3997 - val_accuracy: 0.9115
# Epoch 228/250
# 4/4 [==============================] - 1s 207ms/step - loss: 5.6385e-04 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.9119
# Epoch 229/250
# 4/4 [==============================] - 1s 205ms/step - loss: 1.7299e-04 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.9120
# Epoch 230/250
# 4/4 [==============================] - 1s 201ms/step - loss: 9.9468e-05 - accuracy: 1.0000 - val_loss: 0.4022 - val_accuracy: 0.9117
# Epoch 231/250
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4035 - val_accuracy: 0.9112
# Epoch 232/250
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.9101
# Epoch 233/250
# 4/4 [==============================] - 1s 206ms/step - loss: 5.0334e-04 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.9084
# Epoch 234/250
# 4/4 [==============================] - 1s 205ms/step - loss: 1.7538e-04 - accuracy: 1.0000 - val_loss: 0.4191 - val_accuracy: 0.9066
# Epoch 235/250
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.9080
# Epoch 236/250
# 4/4 [==============================] - 1s 201ms/step - loss: 5.3109e-04 - accuracy: 1.0000 - val_loss: 0.4158 - val_accuracy: 0.9083
# Epoch 237/250
# 4/4 [==============================] - 1s 200ms/step - loss: 2.3824e-04 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.9081
# Epoch 238/250
# 4/4 [==============================] - 1s 196ms/step - loss: 2.2794e-04 - accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.9082
# Epoch 239/250
# 4/4 [==============================] - 1s 217ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4185 - val_accuracy: 0.9076
# Epoch 240/250
# 4/4 [==============================] - 1s 195ms/step - loss: 3.3051e-04 - accuracy: 1.0000 - val_loss: 0.4216 - val_accuracy: 0.9065
# Epoch 241/250
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4239 - val_accuracy: 0.9061
# Epoch 242/250
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4252 - val_accuracy: 0.9060
# Epoch 243/250
# 4/4 [==============================] - 1s 201ms/step - loss: 7.9288e-04 - accuracy: 1.0000 - val_loss: 0.4257 - val_accuracy: 0.9053
# Epoch 244/250
# 4/4 [==============================] - 1s 200ms/step - loss: 8.7467e-05 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9043
# Epoch 245/250
# 4/4 [==============================] - 1s 194ms/step - loss: 7.7548e-05 - accuracy: 1.0000 - val_loss: 0.4280 - val_accuracy: 0.9049
# Epoch 246/250
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.9037
# Epoch 247/250
# 4/4 [==============================] - 1s 193ms/step - loss: 1.7876e-04 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.9035
# Epoch 248/250
# 4/4 [==============================] - 1s 203ms/step - loss: 7.4609e-04 - accuracy: 1.0000 - val_loss: 0.4348 - val_accuracy: 0.9033
# Epoch 249/250
# 4/4 [==============================] - 1s 199ms/step - loss: 1.8055e-04 - accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.9036
# Epoch 250/250
# 4/4 [==============================] - 1s 196ms/step - loss: 4.8136e-04 - accuracy: 1.0000 - val_loss: 0.4356 - val_accuracy: 0.9047
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4356 - accuracy: 0.9047
# [0.43556538224220276, 0.904699981212616]
